# %%
# samarth deshmukh
# 25070123101
# exp 4

# %%
set1={"apple","banana","cherry"}
print(set1)
# Out:
# {'apple', 'banana', 'cherry'}

# %%
set1={"apple","banana","cherry"} # this is wrong remeber it
print(set1[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-626260073.py in <cell line: 0>()
#       1 set1={"apple","banana","cherry"}
# ----> 2 print(set1[1])
#
# TypeError: 'set' object is not subscriptable

# %%
set2={2,2.5,True,"samarth"} # unordered manner
print(set2)
# Out:
# {True, 2, 2.5, 'samarth'}

# %%
set3={"apple",2,True,1,"apple"} # removes duplicate
print(set3)
# Out:
# {True, 2, 'apple'}

# %%
set4={"apple","banana","cherry"}
set4.add("kiwi")
print(set4)
# Out:
# {'kiwi', 'apple', 'banana', 'cherry'}

# %%
set5={"apple","banana","cherry"}
set5.remove("banana")
print(set5)
# Out:
# {'apple', 'cherry'}

# %%
set6={1,2,3,4}
set7={3,4,5,6}
print("union:",set6|set7)
# Out:
# union: {1, 2, 3, 4, 5, 6}

# %%
set6={1,2,3,4}
set7={3,4,5,6}
print("union:",set6|set7)
print("intersection:",set6&set7)
# Out:
# union: {1, 2, 3, 4, 5, 6}
# intersection: {3, 4}

# %%
set6={1,2,3,4}
set7={3,4,5,6}
print("union:",set6|set7)
print("intersection:",set6&set7)
print("difference:",set6-set7)
print("difference:",set7-set6)
# Out:
# union: {1, 2, 3, 4, 5, 6}
# intersection: {3, 4}
# difference: {1, 2}
# difference: {5, 6}

# %%
set6={1,2,3,4}
set7={3,4,5,6}
print("union:",set6|set7)
print("intersection:",set6&set7)
print("difference:",set6-set7)
print("difference:",set7-set6)
print("dsimiliar:",set6^set7)
# Out:
# union: {1, 2, 3, 4, 5, 6}
# intersection: {3, 4}
# difference: {1, 2}
# difference: {5, 6}
# dsimiliar: {1, 2, 5, 6}

# %%
set8=frozenset({"apple","banana","cherry"})
print(set8)
# Out:
# frozenset({'apple', 'banana', 'cherry'})

# %%
set8=frozenset({"apple","banana","cherry"})
print(set8)
print(type(set8))
# Out:
# frozenset({'apple', 'banana', 'cherry'})
# <class 'frozenset'>

# %%
participants = ["Amit", "Raju", "Amit", "Sneha", "Raju", "Rahul"] # 1 problem
unique_participants = set(participants)
print("Unique Event Participants:",unique_participants)
# Out:
# Unique Event Participants: {'Amit', 'Raju', 'Sneha', 'Rahul'}

# %%
student1 = {"Maths", "Physics", "Chemistry"} # 2 problem
student2 = {"Physics", "Chemistry", "Biology"}
student3 = {"Chemistry", "Physics", "English"}
common_subjects = student1 & student2 & student3
print("Common subjects chosen by all students:",common_subjects)
# Out:
# Common subjects chosen by all students: {'Chemistry', 'Physics'}

# %%
cricket = {"Amit", "Rahul", "Sneha"} # 3 problem
football = {"Rahul", "Priya", "Sneha"}
both_clubs = cricket & football
only_one_club = cricket ^ football
print("Students in both clubs:")
print(both_clubs)
print("\nStudents in only one club:")
print(only_one_club)
# Out:
# Students in both clubs:
# {'Rahul', 'Sneha'}
#
# Students in only one club:
# {'Amit', 'Priya'}

# %%
students={"A","B","C","D","E"}
present={"A","C","E"}
absent=students-present
print("absent students:",absent)
# Out:
# absent students: {'D', 'B'}

# %%
course_codes = {"CS101", "EE102", "ME103", "CE104"}
discontinued_course = "ME103"
course_codes.discard(discontinued_course)
print("Updated Course Codes:", course_codes)
# Out:
# Updated Course Codes: {'CS101', 'EE102', 'CE104'}
